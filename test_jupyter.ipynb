# %% [markdown]
# ## 今天是个好天气

# %%
print('今天是个好天气')
# Out:
# 今天是个好天气

# %%
import numpy as np
import matplotlib.pyplot as plt
a = np.arange(10)
plt.plot(a,a*1.5,a,a*2.5,a,a*3.5,a,a*4.5)
plt.show()

# %%
import pandas as pd
s = pd.Series([2,4,6])
s
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
d = pd.DataFrame([
    [2,4,6,8,10],[10,12,14,16,18]])
d[0][1]
# Out:
# 10
